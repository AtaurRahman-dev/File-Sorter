# %%
import os, shutil

# %%
path = r"D:/Data Analyst Course/Python Projects/Automatic File Sorter/"

# %%
file_name = os.listdir(path)

# %%
folder_name = ['csv files', 'xlsx files', 'image files', 'text files']

for loop in range(0,4):
    if not os.path.exists(path + folder_name[loop]):
        print(path + folder_name[loop])
        os.makedirs(path + folder_name[loop])

for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".xlsx" in file and not os.path.exists(path + "xlsx files/" + file):
        shutil.move(path + file, path + "xlsx files/" + file)
    elif ".png" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
# Out:
# D:/Data Analyst Course/Python Projects/Automatic File Sorter/csv files
# D:/Data Analyst Course/Python Projects/Automatic File Sorter/xlsx files
# D:/Data Analyst Course/Python Projects/Automatic File Sorter/image files
# D:/Data Analyst Course/Python Projects/Automatic File Sorter/text files
